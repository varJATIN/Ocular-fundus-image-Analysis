# %% [markdown]
# <a href="https://colab.research.google.com/github/varJATIN/Ocular-fundus-image-Analysis/blob/main/custom_archt_1_microaneurysms.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import sys
import random

import numpy as np
import cv2
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras

from sklearn.utils import shuffle
from matplotlib.pyplot import imread
from cv2 import resize
import matplotlib.pyplot as plt
import cv2
import scipy
## Seeding 
seed = 2
random.seed = seed
#np.random.seed = seed
tf.seed = seed

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def down_block(x, filters, kernel_size=(3, 3), padding="same", strides=1):
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(x)
    c=tf.keras.layers.BatchNormalization()(c)
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(c)
    c=tf.keras.layers.BatchNormalization()(c)
    p = keras.layers.MaxPool2D((2, 2), (2, 2))(c)
    return c, p

def atten(x,g,F_x,F_g,F_int,kernel_size=(3,3), padding="same", strides=1):
    # upsample lower decoder filters
    us = keras.layers.UpSampling2D((2, 2))(g)
    gate = keras.layers.Conv2D(F_g, kernel_size, padding=padding, strides=strides, activation="relu")(us)
    gate=tf.keras.layers.BatchNormalization()(gate)
    
    # convolve the upsampled decoder filter for F_int filters
    W_g=keras.layers.Conv2D(F_int, kernel_size=1, padding=padding, strides=strides)(gate)
    W_g=tf.keras.layers.BatchNormalization()(W_g)
    
    # convolve encoder output for F_int filters
    W_x=keras.layers.Conv2D(F_int, kernel_size=1, padding=padding, strides=strides)(x)
    W_x=tf.keras.layers.BatchNormalization()(W_x)
    
    # convolve to  attention filter
    psi=tf.keras.activations.relu(W_x+W_g, alpha=0.0, max_value=None, threshold=0)
    psi=keras.layers.Conv2D(F_x, kernel_size=1, padding=padding, strides=strides)(psi)
    psi=tf.keras.activations.sigmoid(tf.keras.layers.BatchNormalization()(psi))
    
    # return the filtered encoder output for concat
    return x*psi

def up_block(x, skip, filters, kernel_size=(3, 3), padding="same", strides=1):
    us = keras.layers.UpSampling2D((2, 2))(x)
    us = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(us)
    us = tf.keras.layers.BatchNormalization()(us)
    # here skip is from encoder and x if from dec previous layer 
    filtered_skip=atten(skip,x,filters,filters,filters/2)
    #concat filtrd skip and upsampled us
    concat = keras.layers.Concatenate()([us, filtered_skip])
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(concat)
    c=tf.keras.layers.BatchNormalization()(c)
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(c)
    c=tf.keras.layers.BatchNormalization()(c)
    return c

def bottleneck(x, filters, kernel_size=(3, 3), padding="same", strides=1):
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(x)
    c=tf.keras.layers.BatchNormalization()(c)
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(c)
    c=tf.keras.layers.BatchNormalization()(c) 
    return c

# %%
def UNet_modular(depth=4,f=3,image_size=512):
    """ returns a modular code for the UNet multihead attention with
        deep supervision.
        depth is depth of model excluding bottleneck.
        f is no of filters in first layer.
        image_size is image pixel 
    """
    # define input container with 3 input channels
    input_channels=3
    inputs= keras.layers.Input((image_size, image_size, input_channels))
    pooled_out=inputs
    skip_memory=[]
    filters=[]
    for layer in range(depth):
      filters.append(f*2**layer)
    print(filters)

    for layer in range(depth):
      x,pooled_out=down_block(pooled_out,filters[layer])
      skip_memory.append(x)	

    # bottleneck_factor 
    bn_factor=2**depth
    upsample_out=bottleneck(pooled_out,f*bn_factor)
    upsample_memory=[upsample_out]
    for layer in range(depth):
      upsample_out=up_block(upsample_out,skip_memory[depth-1-layer],filters[depth-1-layer])
      upsample_memory.append(upsample_out)

    #up sample layer
    up=keras.layers.UpSampling2D((2,2))
    #create empty list for storing skip up samples 
    skip_up_list=[]
    # upsample the outputs of upsample layers stored in upsample_memory
    for i in range(depth):
      skip_up=upsample_memory[i]
      for j in range(depth-i):
        skip_up=up(skip_up)
      skip_up_list.append(skip_up)
    skip_up_list.append(upsample_memory[depth])
    deep_supervised = keras.layers.Concatenate()(skip_up_list)
    outputs=keras.layers.Conv2D(1,(1,1),padding="same",activation="sigmoid")(deep_supervised)
    model=keras.models.Model(inputs,outputs)
    return model

# %%
# data
data_location = "/content/drive/My Drive/IDRid/A. Segmentation/1. Original Images/a. Training Set"
train_data = []  # create an empty list
for (dirName, subdirList, fileList) in sorted(os.walk(data_location)):
    for fileName in sorted(fileList):
        if ".jpg" in fileName.lower() :
            train_data.append(os.path.join(dirName,fileName))
 
print(len(train_data))


# groundtruths for hard exudates
target_root_location = "/content/drive/My Drive/IDRid/A. Segmentation/2. All Segmentation Groundtruths/a. Training Set/"
#data_location = "/content/drive/My Drive/IDRid/A. Segmentation/2. All Segmentation Groundtruths/a. Training Set/3. Hard Exudates"
train_data_gt = []  # create an empty list
segs=['1. Microaneurysms','2. Haemorrhages','3. Hard Exudates','4. Soft Exudates']
for seg in segs:
  data_location=target_root_location+seg
  print(data_location)
  seg_mask=[]
  for dirName, subdirList, fileList in sorted(os.walk(data_location)):
      for filename in sorted(fileList):
          if ".tif" in filename.lower() :
              seg_mask.append(os.path.join(dirName,filename))
              #train_data_gt.append(os.path.join(dirName,filename))
  train_data_gt.append(seg_mask)
print(len(train_data_gt));
# Out:
# 54
# /content/drive/My Drive/IDRid/A. Segmentation/2. All Segmentation Groundtruths/a. Training Set/1. Microaneurysms
# /content/drive/My Drive/IDRid/A. Segmentation/2. All Segmentation Groundtruths/a. Training Set/2. Haemorrhages
# /content/drive/My Drive/IDRid/A. Segmentation/2. All Segmentation Groundtruths/a. Training Set/3. Hard Exudates
# /content/drive/My Drive/IDRid/A. Segmentation/2. All Segmentation Groundtruths/a. Training Set/4. Soft Exudates
# 4

# %%
train_batch = np.zeros(shape = (len(train_data)*5, 640,640, 3));
train_label = np.zeros(shape = (len(train_data)*5, 640,640, 1));
rot=[-4,-3,-2,-1,1,2,3,4]
for file_index in range(0,len(train_data)*5,5):
    #print(file_index)
    # image
    train_batch[file_index, :, :,:] = resize(imread(train_data[int(file_index/5)]), (640,640))
    # label
    img = cv2.cvtColor(imread(train_data_gt[0][int(file_index/5)]), cv2.COLOR_BGRA2BGR)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) 
    train_label[file_index, :, :,:] = np.expand_dims(resize(img, (640,640)), axis = 2)
    #print(np.max(train_batch),np.max(train_label))
    #flip
    train_batch[file_index+1, :, :,:]=np.flip(train_batch[file_index, :, :,:],axis=1)
    train_label[file_index+1, :, :,:]=np.flip(train_label[file_index, :, :,:],axis=1)
    #flip
    train_batch[file_index+2, :, :,:]=np.flip(train_batch[file_index, :, :,:],axis=0)
    train_label[file_index+2, :, :,:]=np.flip(train_label[file_index, :, :,:],axis=0)
    #rotate
    train_batch[file_index+3, :, :,:]=np.rot90(np.rot90(train_batch[file_index, :, :,:]))
    train_label[file_index+3, :, :,:]=np.rot90(np.rot90(train_label[file_index, :, :,:]))

    #random rotate
    ang=random.choice(rot)
    train_batch[file_index+4, :, :,:]=scipy.ndimage.rotate(train_batch[file_index, :, :,:],ang,reshape=False)
    train_label[file_index+4, :, :,:]=scipy.ndimage.rotate(train_label[file_index, :, :,:],ang,reshape=False)


train_batch[:,:,:,0]  = (train_batch[:,:,:,0])/np.max(train_batch)# - train_batch[:,:,:,0].min(axis=0)) / (train_batch[:,:,:,0].max(axis=0) - train_batch[:,:,:,0].min(axis=0)+1e-10)
train_batch[:,:,:,1]  = (train_batch[:,:,:,1])/np.max(train_batch)# - train_batch[:,:,:,1].min(axis=0)) / (train_batch[:,:,:,1].max(axis=0) - train_batch[:,:,:,1].min(axis=0)+1e-10)
train_batch[:,:,:,2]  = (train_batch[:,:,:,2])/np.max(train_batch)# - train_batch[:,:,:,2].min(axis=0)) / (train_batch[:,:,:,2].max(axis=0) - train_batch[:,:,:,2].min(axis=0)+1e-10)

train_label[:,:,:,0]  = (train_label[:,:,:,0])/np.max(train_label)# - train_label[:,:,:,0].min(axis=0)) / (train_label[:,:,:,0].max(axis=0) - train_label[:,:,:,0].min(axis=0)+1e-10)
mask = train_label[:,:,:,:] > 0.25
train_label[mask] = 1.0
train_label[~mask] = 0.0

print(train_batch.shape)
print(train_label.shape)
# Out:
# (270, 640, 640, 3)
# (270, 640, 640, 1)

# %%
from keras import backend as K
def dice_loss(y_true, y_pred, smooth=1):
  intersection = K.sum(y_true * y_pred, axis=[1,2,3])
  union = K.sum(y_true, axis=[1,2,3]) + K.sum(y_pred, axis=[1,2,3])
  dice = K.mean((2. * intersection + smooth)/(union + smooth), axis=0)
  return 1-dice

# %%
seed = 2
random.seed = seed
np.random.seed = seed
tf.seed = seed
tf.random.set_seed(2)
depths=[2,3,4]
models=[]
histories=[]
for f in [16]: 
  for depth in [3]:
    opt=keras.optimizers.Adam(learning_rate = 0.001,beta_1=0.80)
    model = UNet_modular(depth=depth,f=f,image_size=640) 
    model.compile(optimizer=opt, loss=dice_loss, metrics=[tf.keras.metrics.MeanIoU(num_classes=2)])   
    early_stopping= tf.keras.callbacks.EarlyStopping(monitor='loss',min_delta	=0.001, patience=8)
    hist = model.fit(x = train_batch, y = train_label, batch_size = 4, epochs = 200, verbose = 1, callbacks=[early_stopping], validation_split = 16/135, shuffle = True)
    models.append(model)
    histories.append(hist)
# Out:
# [16, 32, 64]
# Epoch 1/200
# 60/60 [==============================] - 25s 419ms/step - loss: 0.9946 - mean_io_u: 0.4522 - val_loss: 0.9979 - val_mean_io_u: 0.4993
# Epoch 2/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.9661 - mean_io_u: 0.4258 - val_loss: 0.9975 - val_mean_io_u: 0.4993
# Epoch 3/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.9049 - mean_io_u: 0.4533 - val_loss: 0.9975 - val_mean_io_u: 0.4993
# Epoch 4/200
# 60/60 [==============================] - 23s 391ms/step - loss: 0.8464 - mean_io_u: 0.4710 - val_loss: 0.9975 - val_mean_io_u: 0.4993
# Epoch 5/200
# 60/60 [==============================] - 23s 388ms/step - loss: 0.8103 - mean_io_u: 0.4774 - val_loss: 0.9975 - val_mean_io_u: 0.4993
# Epoch 6/200
# 60/60 [==============================] - 23s 391ms/step - loss: 0.7860 - mean_io_u: 0.4844 - val_loss: 0.9975 - val_mean_io_u: 0.4993
# Epoch 7/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.8224 - mean_io_u: 0.4942 - val_loss: 1.0000 - val_mean_io_u: 0.4993
# Epoch 8/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.7629 - mean_io_u: 0.5083 - val_loss: 0.9969 - val_mean_io_u: 0.4993
# Epoch 9/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.6697 - mean_io_u: 0.5583 - val_loss: 0.9765 - val_mean_io_u: 0.4993
# Epoch 10/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.6464 - mean_io_u: 0.5577 - val_loss: 0.9238 - val_mean_io_u: 0.5013
# Epoch 11/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.6382 - mean_io_u: 0.5714 - val_loss: 0.8598 - val_mean_io_u: 0.5095
# Epoch 12/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.6225 - mean_io_u: 0.5771 - val_loss: 0.7009 - val_mean_io_u: 0.5361
# Epoch 13/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.6184 - mean_io_u: 0.5859 - val_loss: 0.8958 - val_mean_io_u: 0.5059
# Epoch 14/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.6061 - mean_io_u: 0.5863 - val_loss: 0.6563 - val_mean_io_u: 0.5622
# Epoch 15/200
# 60/60 [==============================] - 23s 389ms/step - loss: 0.6125 - mean_io_u: 0.5894 - val_loss: 0.7850 - val_mean_io_u: 0.5304
# Epoch 16/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.6045 - mean_io_u: 0.5935 - val_loss: 0.7389 - val_mean_io_u: 0.5287
# Epoch 17/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.6009 - mean_io_u: 0.5937 - val_loss: 0.8461 - val_mean_io_u: 0.5104
# Epoch 18/200
# 60/60 [==============================] - 23s 389ms/step - loss: 0.5915 - mean_io_u: 0.5960 - val_loss: 0.6386 - val_mean_io_u: 0.5671
# Epoch 19/200
# 60/60 [==============================] - 23s 389ms/step - loss: 0.5925 - mean_io_u: 0.5964 - val_loss: 0.8057 - val_mean_io_u: 0.5217
# Epoch 20/200
# 60/60 [==============================] - 23s 389ms/step - loss: 0.5830 - mean_io_u: 0.5993 - val_loss: 0.6466 - val_mean_io_u: 0.5676
# Epoch 21/200
# 60/60 [==============================] - 23s 389ms/step - loss: 0.5893 - mean_io_u: 0.5991 - val_loss: 0.6876 - val_mean_io_u: 0.5613
# Epoch 22/200
# 60/60 [==============================] - 23s 389ms/step - loss: 0.5874 - mean_io_u: 0.6001 - val_loss: 0.7234 - val_mean_io_u: 0.5402
# Epoch 23/200
# 60/60 [==============================] - 23s 389ms/step - loss: 0.5824 - mean_io_u: 0.6031 - val_loss: 0.6729 - val_mean_io_u: 0.5508
# Epoch 24/200
# 60/60 [==============================] - 23s 391ms/step - loss: 0.5828 - mean_io_u: 0.6002 - val_loss: 0.6162 - val_mean_io_u: 0.5916
# Epoch 25/200
# 60/60 [==============================] - 23s 389ms/step - loss: 0.5681 - mean_io_u: 0.6028 - val_loss: 0.7623 - val_mean_io_u: 0.5307
# Epoch 26/200
# 60/60 [==============================] - 23s 391ms/step - loss: 0.5681 - mean_io_u: 0.6059 - val_loss: 0.6071 - val_mean_io_u: 0.5871
# Epoch 27/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.5825 - mean_io_u: 0.6118 - val_loss: 0.9017 - val_mean_io_u: 0.5084
# Epoch 28/200
# 60/60 [==============================] - 23s 389ms/step - loss: 0.5794 - mean_io_u: 0.6047 - val_loss: 0.6060 - val_mean_io_u: 0.6031
# Epoch 29/200
# 60/60 [==============================] - 23s 389ms/step - loss: 0.5673 - mean_io_u: 0.6058 - val_loss: 0.6697 - val_mean_io_u: 0.5516
# Epoch 30/200
# 60/60 [==============================] - 23s 389ms/step - loss: 0.5521 - mean_io_u: 0.6116 - val_loss: 0.6668 - val_mean_io_u: 0.5559
# Epoch 31/200
# 60/60 [==============================] - 23s 389ms/step - loss: 0.5454 - mean_io_u: 0.6106 - val_loss: 0.6685 - val_mean_io_u: 0.5559
# Epoch 32/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.5573 - mean_io_u: 0.6116 - val_loss: 0.5929 - val_mean_io_u: 0.6075
# Epoch 33/200
# 60/60 [==============================] - 23s 389ms/step - loss: 0.5441 - mean_io_u: 0.6161 - val_loss: 0.6041 - val_mean_io_u: 0.5876
# Epoch 34/200
# 60/60 [==============================] - 23s 389ms/step - loss: 0.5394 - mean_io_u: 0.6127 - val_loss: 0.6198 - val_mean_io_u: 0.5931
# Epoch 35/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.5456 - mean_io_u: 0.6128 - val_loss: 0.6949 - val_mean_io_u: 0.5564
# Epoch 36/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.5318 - mean_io_u: 0.6183 - val_loss: 0.6032 - val_mean_io_u: 0.5994
# Epoch 37/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.5302 - mean_io_u: 0.6158 - val_loss: 0.7025 - val_mean_io_u: 0.5570
# Epoch 38/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.5284 - mean_io_u: 0.6199 - val_loss: 0.6375 - val_mean_io_u: 0.5810
# Epoch 39/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.5270 - mean_io_u: 0.6157 - val_loss: 0.6979 - val_mean_io_u: 0.5554
# Epoch 40/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.5359 - mean_io_u: 0.6183 - val_loss: 0.6714 - val_mean_io_u: 0.5608
# Epoch 41/200
# 60/60 [==============================] - 23s 389ms/step - loss: 0.5172 - mean_io_u: 0.6193 - val_loss: 0.5901 - val_mean_io_u: 0.6131
# Epoch 42/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.5100 - mean_io_u: 0.6272 - val_loss: 0.6426 - val_mean_io_u: 0.5727
# Epoch 43/200
# 60/60 [==============================] - 23s 389ms/step - loss: 0.5394 - mean_io_u: 0.6183 - val_loss: 0.6022 - val_mean_io_u: 0.5945
# Epoch 44/200
# 60/60 [==============================] - 23s 389ms/step - loss: 0.5137 - mean_io_u: 0.6220 - val_loss: 0.6675 - val_mean_io_u: 0.5642
# Epoch 45/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.5030 - mean_io_u: 0.6261 - val_loss: 0.6594 - val_mean_io_u: 0.5805
# Epoch 46/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.5151 - mean_io_u: 0.6201 - val_loss: 0.6704 - val_mean_io_u: 0.5595
# Epoch 47/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.5101 - mean_io_u: 0.6260 - val_loss: 0.6115 - val_mean_io_u: 0.5925
# Epoch 48/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.4976 - mean_io_u: 0.6289 - val_loss: 0.6808 - val_mean_io_u: 0.5516
# Epoch 49/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.4888 - mean_io_u: 0.6331 - val_loss: 0.6106 - val_mean_io_u: 0.5894
# Epoch 50/200
# 60/60 [==============================] - 23s 389ms/step - loss: 0.4923 - mean_io_u: 0.6309 - val_loss: 0.6264 - val_mean_io_u: 0.5817
# Epoch 51/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.4877 - mean_io_u: 0.6336 - val_loss: 0.6141 - val_mean_io_u: 0.5846
# Epoch 52/200
# 60/60 [==============================] - 23s 389ms/step - loss: 0.4949 - mean_io_u: 0.6351 - val_loss: 0.7667 - val_mean_io_u: 0.5362
# Epoch 53/200
# 60/60 [==============================] - 23s 391ms/step - loss: 0.4925 - mean_io_u: 0.6334 - val_loss: 0.7097 - val_mean_io_u: 0.5584
# Epoch 54/200
# 60/60 [==============================] - 23s 389ms/step - loss: 0.5026 - mean_io_u: 0.6333 - val_loss: 0.6537 - val_mean_io_u: 0.5787
# Epoch 55/200
# 60/60 [==============================] - 23s 389ms/step - loss: 0.4945 - mean_io_u: 0.6296 - val_loss: 0.6910 - val_mean_io_u: 0.5553
# Epoch 56/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.4792 - mean_io_u: 0.6351 - val_loss: 0.6935 - val_mean_io_u: 0.5568
# Epoch 57/200
# 60/60 [==============================] - 23s 389ms/step - loss: 0.4753 - mean_io_u: 0.6400 - val_loss: 0.6562 - val_mean_io_u: 0.5764
# Epoch 58/200
# 60/60 [==============================] - 23s 389ms/step - loss: 0.4945 - mean_io_u: 0.6368 - val_loss: 0.5937 - val_mean_io_u: 0.6079
# Epoch 59/200
# 60/60 [==============================] - 23s 389ms/step - loss: 0.4749 - mean_io_u: 0.6346 - val_loss: 0.5976 - val_mean_io_u: 0.6020
# Epoch 60/200
# 60/60 [==============================] - 23s 388ms/step - loss: 0.4779 - mean_io_u: 0.6337 - val_loss: 0.6107 - val_mean_io_u: 0.5922
# Epoch 61/200
# 60/60 [==============================] - 23s 389ms/step - loss: 0.4680 - mean_io_u: 0.6395 - val_loss: 0.7082 - val_mean_io_u: 0.5391
# Epoch 62/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.4645 - mean_io_u: 0.6378 - val_loss: 0.7025 - val_mean_io_u: 0.5563
# Epoch 63/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.4644 - mean_io_u: 0.6387 - val_loss: 0.7190 - val_mean_io_u: 0.5524
# Epoch 64/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.4654 - mean_io_u: 0.6380 - val_loss: 0.6097 - val_mean_io_u: 0.6025
# Epoch 65/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.4865 - mean_io_u: 0.6420 - val_loss: 0.7314 - val_mean_io_u: 0.5518
# Epoch 66/200
# 60/60 [==============================] - 23s 391ms/step - loss: 0.4759 - mean_io_u: 0.6414 - val_loss: 0.6511 - val_mean_io_u: 0.5808
# Epoch 67/200
# 60/60 [==============================] - 23s 389ms/step - loss: 0.4721 - mean_io_u: 0.6435 - val_loss: 0.6054 - val_mean_io_u: 0.6087
# Epoch 68/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.4548 - mean_io_u: 0.6424 - val_loss: 0.6160 - val_mean_io_u: 0.5957
# Epoch 69/200
# 60/60 [==============================] - 23s 389ms/step - loss: 0.4481 - mean_io_u: 0.6452 - val_loss: 0.6435 - val_mean_io_u: 0.5827
# Epoch 70/200
# 60/60 [==============================] - 23s 389ms/step - loss: 0.4465 - mean_io_u: 0.6459 - val_loss: 0.6004 - val_mean_io_u: 0.5999
# Epoch 71/200
# 60/60 [==============================] - 23s 389ms/step - loss: 0.4470 - mean_io_u: 0.6485 - val_loss: 0.6272 - val_mean_io_u: 0.5854
# Epoch 72/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.4501 - mean_io_u: 0.6485 - val_loss: 0.6728 - val_mean_io_u: 0.5693
# Epoch 73/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.4660 - mean_io_u: 0.6476 - val_loss: 0.6264 - val_mean_io_u: 0.5915
# Epoch 74/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.4580 - mean_io_u: 0.6436 - val_loss: 0.6201 - val_mean_io_u: 0.5977
# Epoch 75/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.4456 - mean_io_u: 0.6459 - val_loss: 0.6706 - val_mean_io_u: 0.5705
# Epoch 76/200
# 60/60 [==============================] - 23s 391ms/step - loss: 0.4422 - mean_io_u: 0.6443 - val_loss: 0.6047 - val_mean_io_u: 0.5963
# Epoch 77/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.4401 - mean_io_u: 0.6529 - val_loss: 0.6207 - val_mean_io_u: 0.5935
# Epoch 78/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.4334 - mean_io_u: 0.6545 - val_loss: 0.5948 - val_mean_io_u: 0.6097
# Epoch 79/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.4302 - mean_io_u: 0.6550 - val_loss: 0.6297 - val_mean_io_u: 0.5910
# Epoch 80/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.4389 - mean_io_u: 0.6519 - val_loss: 0.7598 - val_mean_io_u: 0.5399
# Epoch 81/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.4323 - mean_io_u: 0.6526 - val_loss: 0.6762 - val_mean_io_u: 0.5741
# Epoch 82/200
# 60/60 [==============================] - 23s 391ms/step - loss: 0.4324 - mean_io_u: 0.6531 - val_loss: 0.6145 - val_mean_io_u: 0.5917
# Epoch 83/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.4268 - mean_io_u: 0.6553 - val_loss: 0.6119 - val_mean_io_u: 0.6016
# Epoch 84/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.4225 - mean_io_u: 0.6561 - val_loss: 0.6284 - val_mean_io_u: 0.5875
# Epoch 85/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.4197 - mean_io_u: 0.6591 - val_loss: 0.5879 - val_mean_io_u: 0.6141
# Epoch 86/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.4210 - mean_io_u: 0.6574 - val_loss: 0.6071 - val_mean_io_u: 0.6029
# Epoch 87/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.4158 - mean_io_u: 0.6582 - val_loss: 0.6030 - val_mean_io_u: 0.6024
# Epoch 88/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.4114 - mean_io_u: 0.6630 - val_loss: 0.6361 - val_mean_io_u: 0.5906
# Epoch 89/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.4060 - mean_io_u: 0.6638 - val_loss: 0.6905 - val_mean_io_u: 0.5628
# Epoch 90/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.4087 - mean_io_u: 0.6622 - val_loss: 0.6216 - val_mean_io_u: 0.5897
# Epoch 91/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.4123 - mean_io_u: 0.6585 - val_loss: 0.6402 - val_mean_io_u: 0.5834
# Epoch 92/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.4068 - mean_io_u: 0.6628 - val_loss: 0.6717 - val_mean_io_u: 0.5623
# Epoch 93/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.4002 - mean_io_u: 0.6659 - val_loss: 0.6144 - val_mean_io_u: 0.5942
# Epoch 94/200
# 60/60 [==============================] - 23s 389ms/step - loss: 0.3973 - mean_io_u: 0.6692 - val_loss: 0.6408 - val_mean_io_u: 0.5872
# Epoch 95/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.4063 - mean_io_u: 0.6648 - val_loss: 0.6835 - val_mean_io_u: 0.5694
# Epoch 96/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.3986 - mean_io_u: 0.6669 - val_loss: 0.6233 - val_mean_io_u: 0.5912
# Epoch 97/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.3998 - mean_io_u: 0.6678 - val_loss: 0.8906 - val_mean_io_u: 0.5181
# Epoch 98/200
# 60/60 [==============================] - 23s 391ms/step - loss: 0.4186 - mean_io_u: 0.6574 - val_loss: 0.6501 - val_mean_io_u: 0.5805
# Epoch 99/200
# 60/60 [==============================] - 23s 391ms/step - loss: 0.3924 - mean_io_u: 0.6693 - val_loss: 0.6070 - val_mean_io_u: 0.6002
# Epoch 100/200
# 60/60 [==============================] - 23s 391ms/step - loss: 0.3923 - mean_io_u: 0.6706 - val_loss: 0.6120 - val_mean_io_u: 0.6060
# Epoch 101/200
# 60/60 [==============================] - 23s 389ms/step - loss: 0.3884 - mean_io_u: 0.6762 - val_loss: 0.6329 - val_mean_io_u: 0.5853
# Epoch 102/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.3810 - mean_io_u: 0.6763 - val_loss: 0.6249 - val_mean_io_u: 0.5923
# Epoch 103/200
# 60/60 [==============================] - 23s 389ms/step - loss: 0.3881 - mean_io_u: 0.6775 - val_loss: 0.6665 - val_mean_io_u: 0.5744
# Epoch 104/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.3936 - mean_io_u: 0.6681 - val_loss: 0.7171 - val_mean_io_u: 0.5514
# Epoch 105/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.3968 - mean_io_u: 0.6701 - val_loss: 0.6404 - val_mean_io_u: 0.5859
# Epoch 106/200
# 60/60 [==============================] - 23s 389ms/step - loss: 0.3833 - mean_io_u: 0.6779 - val_loss: 0.6050 - val_mean_io_u: 0.6049
# Epoch 107/200
# 60/60 [==============================] - 23s 389ms/step - loss: 0.3832 - mean_io_u: 0.6777 - val_loss: 0.6294 - val_mean_io_u: 0.5891
# Epoch 108/200
# 60/60 [==============================] - 23s 388ms/step - loss: 0.3761 - mean_io_u: 0.6774 - val_loss: 0.6367 - val_mean_io_u: 0.5885
# Epoch 109/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.3755 - mean_io_u: 0.6768 - val_loss: 0.6402 - val_mean_io_u: 0.5842
# Epoch 110/200
# 60/60 [==============================] - 23s 388ms/step - loss: 0.3722 - mean_io_u: 0.6810 - val_loss: 0.6341 - val_mean_io_u: 0.5870
# Epoch 111/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.3968 - mean_io_u: 0.6737 - val_loss: 0.7101 - val_mean_io_u: 0.5607
# Epoch 112/200
# 60/60 [==============================] - 23s 389ms/step - loss: 0.3832 - mean_io_u: 0.6769 - val_loss: 0.6226 - val_mean_io_u: 0.5973
# Epoch 113/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.3830 - mean_io_u: 0.6796 - val_loss: 0.6127 - val_mean_io_u: 0.6019
# Epoch 114/200
# 60/60 [==============================] - 23s 388ms/step - loss: 0.3823 - mean_io_u: 0.6796 - val_loss: 0.6221 - val_mean_io_u: 0.5963
# Epoch 115/200
# 60/60 [==============================] - 23s 389ms/step - loss: 0.3719 - mean_io_u: 0.6826 - val_loss: 0.6378 - val_mean_io_u: 0.5845
# Epoch 116/200
# 60/60 [==============================] - 23s 389ms/step - loss: 0.3755 - mean_io_u: 0.6805 - val_loss: 0.5991 - val_mean_io_u: 0.6045
# Epoch 117/200
# 60/60 [==============================] - 23s 389ms/step - loss: 0.3679 - mean_io_u: 0.6864 - val_loss: 0.5962 - val_mean_io_u: 0.6041
# Epoch 118/200
# 60/60 [==============================] - 23s 389ms/step - loss: 0.3682 - mean_io_u: 0.6839 - val_loss: 0.6654 - val_mean_io_u: 0.5750
# Epoch 119/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.3663 - mean_io_u: 0.6828 - val_loss: 0.5848 - val_mean_io_u: 0.6150
# Epoch 120/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.3716 - mean_io_u: 0.6885 - val_loss: 0.6541 - val_mean_io_u: 0.5807
# Epoch 121/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.3681 - mean_io_u: 0.6857 - val_loss: 0.6811 - val_mean_io_u: 0.5684
# Epoch 122/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.3625 - mean_io_u: 0.6905 - val_loss: 0.6535 - val_mean_io_u: 0.5807
# Epoch 123/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.3613 - mean_io_u: 0.6894 - val_loss: 0.6313 - val_mean_io_u: 0.5954
# Epoch 124/200
# 60/60 [==============================] - 23s 391ms/step - loss: 0.3724 - mean_io_u: 0.6850 - val_loss: 0.6865 - val_mean_io_u: 0.5720
# Epoch 125/200
# 60/60 [==============================] - 23s 391ms/step - loss: 0.3629 - mean_io_u: 0.6850 - val_loss: 0.6154 - val_mean_io_u: 0.5993
# Epoch 126/200
# 60/60 [==============================] - 23s 391ms/step - loss: 0.3655 - mean_io_u: 0.6874 - val_loss: 0.7296 - val_mean_io_u: 0.5525
# Epoch 127/200
# 60/60 [==============================] - 23s 391ms/step - loss: 0.3592 - mean_io_u: 0.6924 - val_loss: 0.6483 - val_mean_io_u: 0.5797
# Epoch 128/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.3634 - mean_io_u: 0.6852 - val_loss: 0.7374 - val_mean_io_u: 0.5490
# Epoch 129/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.3657 - mean_io_u: 0.6880 - val_loss: 0.6173 - val_mean_io_u: 0.6001
# Epoch 130/200
# 60/60 [==============================] - 23s 389ms/step - loss: 0.3511 - mean_io_u: 0.6942 - val_loss: 0.6605 - val_mean_io_u: 0.5812
# Epoch 131/200
# 60/60 [==============================] - 23s 389ms/step - loss: 0.3564 - mean_io_u: 0.6901 - val_loss: 0.6651 - val_mean_io_u: 0.5718
# Epoch 132/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.3498 - mean_io_u: 0.6941 - val_loss: 0.6450 - val_mean_io_u: 0.5858
# Epoch 133/200
# 60/60 [==============================] - 23s 389ms/step - loss: 0.3492 - mean_io_u: 0.6975 - val_loss: 0.6066 - val_mean_io_u: 0.6100
# Epoch 134/200
# 60/60 [==============================] - 23s 389ms/step - loss: 0.3567 - mean_io_u: 0.6884 - val_loss: 0.7345 - val_mean_io_u: 0.5589
# Epoch 135/200
# 60/60 [==============================] - 23s 389ms/step - loss: 0.3529 - mean_io_u: 0.6935 - val_loss: 0.6679 - val_mean_io_u: 0.5751
# Epoch 136/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.3444 - mean_io_u: 0.6999 - val_loss: 0.6625 - val_mean_io_u: 0.5800
# Epoch 137/200
# 60/60 [==============================] - 23s 389ms/step - loss: 0.3460 - mean_io_u: 0.6979 - val_loss: 0.6388 - val_mean_io_u: 0.5903
# Epoch 138/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.3430 - mean_io_u: 0.6959 - val_loss: 0.6288 - val_mean_io_u: 0.5980
# Epoch 139/200
# 60/60 [==============================] - 23s 389ms/step - loss: 0.3477 - mean_io_u: 0.6973 - val_loss: 0.6846 - val_mean_io_u: 0.5715
# Epoch 140/200
# 60/60 [==============================] - 23s 388ms/step - loss: 0.3579 - mean_io_u: 0.6955 - val_loss: 0.6300 - val_mean_io_u: 0.5881
# Epoch 141/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.3419 - mean_io_u: 0.6985 - val_loss: 0.6512 - val_mean_io_u: 0.5816
# Epoch 142/200
# 60/60 [==============================] - 23s 389ms/step - loss: 0.3410 - mean_io_u: 0.7011 - val_loss: 0.6634 - val_mean_io_u: 0.5800
# Epoch 143/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.3385 - mean_io_u: 0.6984 - val_loss: 0.6389 - val_mean_io_u: 0.5919
# Epoch 144/200
# 60/60 [==============================] - 23s 389ms/step - loss: 0.3456 - mean_io_u: 0.7012 - val_loss: 0.6528 - val_mean_io_u: 0.5787
# Epoch 145/200
# 60/60 [==============================] - 23s 389ms/step - loss: 0.3415 - mean_io_u: 0.7028 - val_loss: 0.6343 - val_mean_io_u: 0.5911
# Epoch 146/200
# 60/60 [==============================] - 23s 389ms/step - loss: 0.3568 - mean_io_u: 0.6967 - val_loss: 0.6124 - val_mean_io_u: 0.6006
# Epoch 147/200
# 60/60 [==============================] - 23s 389ms/step - loss: 0.3470 - mean_io_u: 0.6946 - val_loss: 0.6274 - val_mean_io_u: 0.5948
# Epoch 148/200
# 60/60 [==============================] - 23s 389ms/step - loss: 0.3404 - mean_io_u: 0.6967 - val_loss: 0.6241 - val_mean_io_u: 0.5955
# Epoch 149/200
# 60/60 [==============================] - 23s 391ms/step - loss: 0.3401 - mean_io_u: 0.7008 - val_loss: 0.6280 - val_mean_io_u: 0.5972
# Epoch 150/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.3348 - mean_io_u: 0.7009 - val_loss: 0.6071 - val_mean_io_u: 0.6076
# Epoch 151/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.3298 - mean_io_u: 0.7031 - val_loss: 0.6168 - val_mean_io_u: 0.5998
# Epoch 152/200
# 60/60 [==============================] - 23s 389ms/step - loss: 0.3290 - mean_io_u: 0.7043 - val_loss: 0.6473 - val_mean_io_u: 0.5847
# Epoch 153/200
# 60/60 [==============================] - 23s 389ms/step - loss: 0.3313 - mean_io_u: 0.7064 - val_loss: 0.6636 - val_mean_io_u: 0.5793
# Epoch 154/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.3299 - mean_io_u: 0.7052 - val_loss: 0.6381 - val_mean_io_u: 0.5889
# Epoch 155/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.3358 - mean_io_u: 0.7013 - val_loss: 0.6385 - val_mean_io_u: 0.5929
# Epoch 156/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.3324 - mean_io_u: 0.7014 - val_loss: 0.7783 - val_mean_io_u: 0.5443
# Epoch 157/200
# 60/60 [==============================] - 23s 389ms/step - loss: 0.3314 - mean_io_u: 0.7044 - val_loss: 0.6327 - val_mean_io_u: 0.5982
# Epoch 158/200
# 60/60 [==============================] - 23s 391ms/step - loss: 0.3254 - mean_io_u: 0.7076 - val_loss: 0.6523 - val_mean_io_u: 0.5827
# Epoch 159/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.3261 - mean_io_u: 0.7069 - val_loss: 0.6459 - val_mean_io_u: 0.5881
# Epoch 160/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.3349 - mean_io_u: 0.7080 - val_loss: 0.6374 - val_mean_io_u: 0.5983
# Epoch 161/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.3302 - mean_io_u: 0.7066 - val_loss: 0.6776 - val_mean_io_u: 0.5764
# Epoch 162/200
# 60/60 [==============================] - 23s 391ms/step - loss: 0.3303 - mean_io_u: 0.7109 - val_loss: 0.6457 - val_mean_io_u: 0.5895
# Epoch 163/200
# 60/60 [==============================] - 23s 389ms/step - loss: 0.3449 - mean_io_u: 0.7001 - val_loss: 0.6558 - val_mean_io_u: 0.5907
# Epoch 164/200
# 60/60 [==============================] - 23s 389ms/step - loss: 0.3440 - mean_io_u: 0.7026 - val_loss: 0.6593 - val_mean_io_u: 0.5891
# Epoch 165/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.3377 - mean_io_u: 0.7030 - val_loss: 0.6155 - val_mean_io_u: 0.6003
# Epoch 166/200
# 60/60 [==============================] - 23s 390ms/step - loss: 0.3380 - mean_io_u: 0.7028 - val_loss: 0.6439 - val_mean_io_u: 0.5889

# %%
 j=0
k=0
for i,hist in enumerate(histories):
  plt.plot(hist.history['loss'],label="{} layers and {} starting filters".format(depths[j],4))
  j+=1
  if j%3==0:
    j=0
    k+=1
plt.legend()
plt.title('loss')
plt.show()

# %%
j=0
k=0
for i,hist in enumerate(histories):
  plt.plot(hist.history['mean_io_u_{}'.format(str(1+i))],label="{} layers and {} starting filters".format(depths[j],4))
  j+=1
  if j%3==0:
    j=0
    k+=1
plt.legend()
plt.title('mean_io_u score')
plt.show()

# %% [markdown]
# #test data

# %%
# data
data_location = "/content/drive/My Drive/IDRid/A. Segmentation/1. Original Images/b. Testing Set"
test_data = []  # create an empty list
for (dirName, subdirList, fileList) in sorted(os.walk(data_location)):
    for fileName in sorted(fileList):
        if ".jpg" in fileName.lower() :
            test_data.append(os.path.join(dirName,fileName))
    
print(len(test_data))
target_root_location = "/content/drive/My Drive/IDRid/A. Segmentation/2. All Segmentation Groundtruths/b. Testing Set/"

test_data_gt = []  # create an empty list
segs=['1. Microaneurysms','2. Haemorrhages','3. Hard Exudates','4. Soft Exudates']
for seg in segs:
  data_location=target_root_location+seg
  print(data_location)
  seg_mask=[]
  for dirName, subdirList, fileList in sorted(os.walk(data_location)):
      for filename in sorted(fileList):
          if ".tif" in filename.lower() :
              seg_mask.append(os.path.join(dirName,filename))
              
  test_data_gt.append(seg_mask)
print(len(test_data_gt));
# Out:
# 27
# /content/drive/My Drive/IDRid/A. Segmentation/2. All Segmentation Groundtruths/b. Testing Set/1. Microaneurysms
# /content/drive/My Drive/IDRid/A. Segmentation/2. All Segmentation Groundtruths/b. Testing Set/2. Haemorrhages
# /content/drive/My Drive/IDRid/A. Segmentation/2. All Segmentation Groundtruths/b. Testing Set/3. Hard Exudates
# /content/drive/My Drive/IDRid/A. Segmentation/2. All Segmentation Groundtruths/b. Testing Set/4. Soft Exudates
# 4

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import f1_score
from sklearn.metrics import auc
from sklearn.metrics import precision_recall_curve,precision_score,recall_score

# %%
test_batch = np.zeros(shape = (len(test_data), 640,640, 3));
for file_index in range(0,len(test_data)):
    #print(file_index)
    # image
    test_batch[file_index, :, :,:] = resize(imread(test_data[int(file_index)]), (640, 640))

# Normalize
test_batch  = test_batch/255
test_label = np.zeros(shape = (len(test_data_gt[0]), 640,640, 1));
# but i am filing the test_label serially ie if one mask is not there i am not leaving that place balnk but filing the next mask in its place
for file_index in range(0,len(test_data_gt[0])):  
  img = cv2.cvtColor(imread(test_data_gt[0][file_index]), cv2.COLOR_BGRA2BGR)
  img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) 
  test_label[file_index, :, :,:] = np.expand_dims(resize(img, (640,640)), axis = 2)
# scale to 0-1
test_label[:,:,:,0]  = (test_label[:,:,:,0])/np.max(test_label)# - test_label[:,:,:,0].min(axis=0)) / (test_label[:,:,:,0].max(axis=0) - test_label[:,:,:,0].min(axis=0)+1e-10)
# binarize the masks
mask = test_label[:,:,:,:] > 0.25
test_label[mask] = 1
test_label[~mask] = 0

# %%
predicted_test_label=np.zeros(test_label.shape)
for i in range(27):
  #print(np.expand_dims(test_batch[i],axis=0).shape)
  predicted_test_label[i]=model.predict(np.expand_dims(test_batch[i],axis=0))

# %%
#predicted_train_label=np.zeros((27,640,640,1))
#for i in range(27):
  #print(np.expand_dims(test_batch[i],axis=0).shape)
#  predicted_train_label[i]=model.predict(np.expand_dims(train_batch[i],axis=0))

# %%
for i,model in enumerate(models):
  print(i+3, "layers")
  #generate the masks
  
  #predicted_test_label=model.predict(test_batch)
  
  # ROC
  test_auc = roc_auc_score(test_label.reshape(-1),predicted_test_label.reshape(-1))
  #train_auc = roc_auc_score(train_label.reshape(-1),predicted_train_label.reshape(-1))
  print("train ",0," test roc",test_auc)

  # F1
  testy, yhat_classes=(test_label.reshape(-1),np.round(predicted_test_label.reshape(-1)))
  test_f1 = f1_score(testy, yhat_classes)
  #testy, yhat_classes=train_label.reshape(-1),np.round(predicted_train_label.reshape(-1))
  #train_f1 = f1_score(testy, yhat_classes)
  train_f1=0
  print('Train  F1 score: %f' % train_f1,'Test F1 score: %f' % test_f1)

  
  #accuracy
  accuracy = accuracy_score(testy, yhat_classes)
  print('Accuracy: %f' % accuracy)
  #AUPR
  
  test_aupr = precision_recall_curve(test_label.reshape(-1),predicted_test_label.reshape(-1))
  train_auc=0
  test_auc=auc(test_aupr[1],test_aupr[0] )
  print("natural threshold train AUPR",train_auc," test AUPR",test_auc)
  
  #plot Precision recall curve
  plt.plot(test_aupr[1],test_aupr[0])
  plt.ylabel('Precision')
  plt.xlabel('Recall')
  plt.show()
  #del predicted_test_label
# Out:
# 3 layers
# train  0  test roc 0.7244616699062959
# Train  F1 score: 0.000000 Test F1 score: 0.390867
# Accuracy: 0.999021
# natural threshold train AUPR 0  test AUPR 0.2766122239273994

# %%
 #predicted_test_label=models[1].predict(test_batch)
print(predicted_test_label[0].shape)
for i in range(14):
    plt.imshow(test_batch[i,:,:,:])
    plt.title("Image")
    plt.show()  
    plt.imshow(np.squeeze(predicted_test_label[i,:,:,:], axis = 2),cmap='gray')
    plt.title("Predicted mask")
    plt.show()
    plt.imshow(np.squeeze(test_label[i,:,:,:], axis = 2), cmap='gray')
    plt.title("Actual mask")
    plt.show()
# Out:
# (640, 640, 1)

# %%
predicted_test_label=models[0].predict(test_batch)
print(predicted_test_label[0].shape)
for i in range(14):
    plt.imshow(test_batch[i,:,:,:])
    plt.title("Image")
    plt.show()  
    plt.imshow(np.squeeze(predicted_test_label[i,:,:,:], axis = 2),cmap='gray')
    plt.title("Predicted mask")
    plt.show()
    plt.imshow(np.squeeze(test_label[i,:,:,:], axis = 2), cmap='gray')
    plt.title("Actual mask")
    plt.show()
# Out:
# (640, 640, 1)
