# %% [markdown]
# <a href="https://colab.research.google.com/github/varJATIN/Ocular-fundus-image-Analysis/blob/main/Seg_using_Ben_processed_MA_cstm_arch1_2l_26f_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import sys
import random

import numpy as np
import cv2
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras

from sklearn.utils import shuffle
from matplotlib.pyplot import imread
from cv2 import resize
import matplotlib.pyplot as plt
import cv2
import scipy

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def down_block(x, filters, kernel_size=(3, 3), padding="same", strides=1):
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(x)
    c=tf.keras.layers.BatchNormalization()(c)
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(c)
    c=tf.keras.layers.BatchNormalization()(c)
    p = keras.layers.MaxPool2D((2, 2), (2, 2))(c)
    return c, p

def atten(x,g,F_x,F_g,F_int,kernel_size=(3,3), padding="same", strides=1):
    # upsample lower decoder filters
    us = keras.layers.UpSampling2D((2, 2))(g)
    gate = keras.layers.Conv2D(F_g, kernel_size, padding=padding, strides=strides, activation="relu")(us)
    gate=tf.keras.layers.BatchNormalization()(gate)
    
    # convolve the upsampled decoder filter for F_int filters
    W_g=keras.layers.Conv2D(F_int, kernel_size=1, padding=padding, strides=strides)(gate)
    W_g=tf.keras.layers.BatchNormalization()(W_g)
    
    # convolve encoder output for F_int filters
    W_x=keras.layers.Conv2D(F_int, kernel_size=1, padding=padding, strides=strides)(x)
    W_x=tf.keras.layers.BatchNormalization()(W_x)
    
    # convolve to  attention filter
    psi=tf.keras.activations.relu(W_x+W_g, alpha=0.0, max_value=None, threshold=0)
    psi=keras.layers.Conv2D(F_x, kernel_size=1, padding=padding, strides=strides)(psi)
    psi=tf.keras.activations.sigmoid(tf.keras.layers.BatchNormalization()(psi))
    
    # return the filtered encoder output for concat
    return x*psi

def up_block(x, skip, filters, kernel_size=(3, 3), padding="same", strides=1):
    us = keras.layers.UpSampling2D((2, 2))(x)
    us = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(us)
    us = tf.keras.layers.BatchNormalization()(us)
    # here skip is from encoder and x if from dec previous layer 
    filtered_skip=atten(skip,x,filters,filters,filters/2)
    #concat filtrd skip and upsampled us
    concat = keras.layers.Concatenate()([us, filtered_skip])
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(concat)
    c=tf.keras.layers.BatchNormalization()(c)
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(c)
    c=tf.keras.layers.BatchNormalization()(c)
    return c

def bottleneck(x, filters, kernel_size=(3, 3), padding="same", strides=1):
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(x)
    c=tf.keras.layers.BatchNormalization()(c)
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(c)
    c=tf.keras.layers.BatchNormalization()(c) 
    return c

# %%
def UNet_modular(depth=4,f=3,image_size=512):
    """ returns a modular code for the UNet multihead attention with
        deep supervision.
        depth is depth of model excluding bottleneck.
        f is no of filters in first layer.
        image_size is image pixel 
    """
    # define input container with 3 input channels
    input_channels=3
    inputs= keras.layers.Input((image_size, image_size, input_channels))
    pooled_out=inputs
    skip_memory=[]
    filters=[]
    for layer in range(depth):
      filters.append(f*2**layer)
    print(filters)

    for layer in range(depth):
      x,pooled_out=down_block(pooled_out,filters[layer])
      skip_memory.append(x)	

    # bottleneck_factor 
    bn_factor=2**depth
    upsample_out=bottleneck(pooled_out,f*bn_factor)
    upsample_memory=[upsample_out]
    for layer in range(depth):
      upsample_out=up_block(upsample_out,skip_memory[depth-1-layer],filters[depth-1-layer])
      upsample_memory.append(upsample_out)

    #up sample layer
    up=keras.layers.UpSampling2D((2,2))
    #create empty list for storing skip up samples 
    skip_up_list=[]
    # upsample the outputs of upsample layers stored in upsample_memory
    for i in range(depth):
      skip_up=upsample_memory[i]
      for j in range(depth-i):
        skip_up=up(skip_up)
      skip_up_list.append(skip_up)
    skip_up_list.append(upsample_memory[depth])
    deep_supervised = keras.layers.Concatenate()(skip_up_list)
    outputs=keras.layers.Conv2D(1,(1,1),padding="same",activation="sigmoid")(deep_supervised)
    model=keras.models.Model(inputs,outputs)
    return model

# %%
# data
data_location = "/content/drive/My Drive/IDRid/A. Segmentation/1. Original Images/a. Training Set"
train_data = []  # create an empty list
for (dirName, subdirList, fileList) in sorted(os.walk(data_location)):
    for fileName in sorted(fileList):
        if ".jpg" in fileName.lower() :
            train_data.append(os.path.join(dirName,fileName))
 
print(len(train_data))


# groundtruths for hard exudates
target_root_location = "/content/drive/My Drive/IDRid/A. Segmentation/2. All Segmentation Groundtruths/a. Training Set/"
#data_location = "/content/drive/My Drive/IDRid/A. Segmentation/2. All Segmentation Groundtruths/a. Training Set/3. Hard Exudates"
train_data_gt = []  # create an empty list
segs=['1. Microaneurysms','2. Haemorrhages','3. Hard Exudates','4. Soft Exudates']
for seg in segs:
  data_location=target_root_location+seg
  print(data_location)
  seg_mask=[]
  for dirName, subdirList, fileList in sorted(os.walk(data_location)):
      for filename in sorted(fileList):
          if ".tif" in filename.lower() :
              seg_mask.append(os.path.join(dirName,filename))
              #train_data_gt.append(os.path.join(dirName,filename))
  train_data_gt.append(seg_mask)
print(len(train_data_gt));
# Out:
# 54
# /content/drive/My Drive/IDRid/A. Segmentation/2. All Segmentation Groundtruths/a. Training Set/1. Microaneurysms
# /content/drive/My Drive/IDRid/A. Segmentation/2. All Segmentation Groundtruths/a. Training Set/2. Haemorrhages
# /content/drive/My Drive/IDRid/A. Segmentation/2. All Segmentation Groundtruths/a. Training Set/3. Hard Exudates
# /content/drive/My Drive/IDRid/A. Segmentation/2. All Segmentation Groundtruths/a. Training Set/4. Soft Exudates
# 4

# %%
def crop_image_from_gray(img, tol=8):
    # If for some reason we only have two channels
    if img.ndim == 2:
        mask = img > tol
        return img[np.ix_(mask.any(1),mask.any(0))]
    # If we have a normal RGB images
    elif img.ndim == 3:
        gray_img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
        mask = gray_img > tol
        check_shape = img[:,:,0][np.ix_(mask.any(1),mask.any(0))].shape[0]
        if (check_shape == 0): # image is too dark so that we crop out everything,
            return img # return original image
        else:
            img1=img[:,:,0][np.ix_(mask.any(1),mask.any(0))]
            img2=img[:,:,1][np.ix_(mask.any(1),mask.any(0))]
            img3=img[:,:,2][np.ix_(mask.any(1),mask.any(0))]
            img = np.stack([img1,img2,img3],axis=-1)
        return img,mask
def preprocess_image(image,label, sigmaX=8):
    IMG_WIDTH=512
    image,mask = crop_image_from_gray(image)
    image = cv2.resize(image, (IMG_WIDTH, IMG_WIDTH))
    #print(image.shape,label.shape)
    image = cv2.addWeighted (image,4, cv2.GaussianBlur(image, (0,0) ,sigmaX), -4, 128)
    label = label[:,:][np.ix_(mask.any(1),mask.any(0))]
    return image,label

# %%
train_batch = np.zeros(shape = (len(train_data_gt[0])*5, 512, 512, 3));
train_label = np.zeros(shape = (len(train_data_gt[0])*5, 512, 512, 1));
rot=[-4,-3,-2,-1,1,2,3,4]
img_index=0
lbl_index=0
img_inds=[]
for file_index in range(0,len(train_data_gt[0])*5,5):
    """first load the lbl acc to file_index then load img corressponding to the lbl_index"""
    # label
    lbl = cv2.cvtColor(imread(train_data_gt[0][int(file_index/5)]), cv2.COLOR_BGRA2BGR)
    lbl = cv2.cvtColor(lbl, cv2.COLOR_BGR2GRAY) 
    lbl_index=int(train_data_gt[0][int(file_index/5)][-9:-7])
    img_index=lbl_index-1
    img_inds.append(img_index)
    # image
    img=imread(train_data[img_index])
    #process
    img,lbl=preprocess_image(img,lbl)
    train_batch[file_index, :, :,:],train_label[file_index, :, :,:]  = img,np.expand_dims(resize(lbl, (512, 512)), axis = 2)
    #flip
    train_batch[file_index+1, :, :,:]=np.flip(train_batch[file_index, :, :,:],axis=1)
    train_label[file_index+1, :, :,:]=np.flip(train_label[file_index, :, :,:],axis=1)
    #flip
    train_batch[file_index+2, :, :,:]=np.flip(train_batch[file_index, :, :,:],axis=0)
    train_label[file_index+2, :, :,:]=np.flip(train_label[file_index, :, :,:],axis=0)
    #rotate
    train_batch[file_index+3, :, :,:]=np.rot90(np.rot90(train_batch[file_index, :, :,:]))
    train_label[file_index+3, :, :,:]=np.rot90(np.rot90(train_label[file_index, :, :,:]))

    #random rotate
    ang=random.choice(rot)
    train_batch[file_index+4, :, :,:]=scipy.ndimage.rotate(train_batch[file_index, :, :,:],ang,reshape=False)
    train_label[file_index+4, :, :,:]=scipy.ndimage.rotate(train_label[file_index, :, :,:],ang,reshape=False)

train_batch[:,:,:,0]  = (train_batch[:,:,:,0])/255# - train_images[:,:,:,0].min(axis=0)) / (train_images[:,:,:,0].max(axis=0) - train_images[:,:,:,0].min(axis=0)+1e-10)
train_batch[:,:,:,1]  = (train_batch[:,:,:,1])/255# - train_images[:,:,:,1].min(axis=0)) / (train_images[:,:,:,1].max(axis=0) - train_images[:,:,:,1].min(axis=0)+1e-10)
train_batch[:,:,:,2]  = (train_batch[:,:,:,2])/255# - train_images[:,:,:,2].min(axis=0)) / (train_images[:,:,:,2].max(axis=0) - train_images[:,:,:,2].min(axis=0)+1e-10)

train_label  = train_label / np.max(train_label)
mask = train_label[:,:,:,:] > 0.3
train_label[mask] = 1.0
train_label[~mask] = 0.0

print(train_batch.shape)
print(train_label.shape)
# Out:
# (270, 512, 512, 3)
# (270, 512, 512, 1)

# %%
len(img_inds)
# Out:
# 54

# %%
for i in range(0,5,5):
  #verify if mask and images are loaded correctly 
  plt.imshow(resize(imread(train_data[img_inds[int(i/5)]]),(512,512)))
  plt.show()
  plt.imshow(resize(imread(train_data_gt[0][int(i/5)]),(512,512)))
  plt.show()
  plt.imshow(train_batch[i])
  plt.show()
  plt.imshow(np.squeeze(train_label[i],axis=2))
  plt.show()

# %%
print(np.max(train_batch),np.max(train_label))
# Out:
# 1.2271961835260845 1.0

# %%
from keras import backend as K
def dice_loss(y_true, y_pred, smooth=1):
  intersection = K.sum(y_true * y_pred, axis=[1,2,3])
  union = K.sum(y_true, axis=[1,2,3]) + K.sum(y_pred, axis=[1,2,3])
  dice = K.mean((2. * intersection + smooth)/(union + smooth), axis=0)
  return 1-dice

# %%
from keras.preprocessing.image import ImageDataGenerator
data_gen_args = dict(rotation_range=10,
                     width_shift_range=1.05,
                     height_shift_range=0.05,
                     zoom_range=[0.95,1],
                     fill_mode='nearest')
image_datagen = ImageDataGenerator(**data_gen_args)
mask_datagen = ImageDataGenerator(**data_gen_args)
seed=42
image_datagen.fit(train_batch, augment=True, seed=seed)
mask_datagen.fit(train_label, augment=True, seed=seed)
image_generator = image_datagen.flow(train_batch,seed=seed,batch_size=4)
mask_generator = mask_datagen.flow(train_label,seed=seed,batch_size=4)
gen=zip(image_generator, mask_generator)

# %%
random.seed = seed
np.random.seed(seed)
tf.seed = seed
tf.random.set_seed(42)
configs=[[3,14],[3,16],[2,28]]
models=[]
histories=[]
for config in configs:
  opt=keras.optimizers.Adam(learning_rate = 0.001,beta_1=0.50)
  model = UNet_modular(depth=config[0],f=config[1]) 
  model.compile(optimizer=opt, loss=dice_loss, metrics=[tf.keras.metrics.MeanIoU(num_classes=2)])   
  early_stopping= tf.keras.callbacks.EarlyStopping(monitor='loss',min_delta	=0.001, patience=6)
  rlrop=tf.keras.callbacks.ReduceLROnPlateau(monitor='loss', factor=0.5, patience=6,verbose=1,mode='auto', min_delta=0.01) 
  hist = model.fit(gen, steps_per_epoch=len(image_generator), epochs = 200, verbose = 1, callbacks=[early_stopping,rlrop])
  #hist = model.fit(x = train_batch, y = train_label, batch_size = 4, epochs = 200, verbose = 1, callbacks=[early_stopping], validation_split = 8/150, shuffle = True)
  models.append(model)
  histories.append(hist)
# Out:
# [14, 28, 56]
# Epoch 1/200
# 68/68 [==============================] - 26s 335ms/step - loss: 0.9936 - mean_io_u_6: 0.4745
# Epoch 2/200
# 68/68 [==============================] - 23s 335ms/step - loss: 0.9673 - mean_io_u_6: 0.4558
# Epoch 3/200
# 68/68 [==============================] - 23s 337ms/step - loss: 0.8931 - mean_io_u_6: 0.4683
# Epoch 4/200
# 68/68 [==============================] - 23s 332ms/step - loss: 0.8009 - mean_io_u_6: 0.5017
# Epoch 5/200
# 68/68 [==============================] - 23s 339ms/step - loss: 0.7718 - mean_io_u_6: 0.5233
# Epoch 6/200
# 68/68 [==============================] - 23s 337ms/step - loss: 0.6891 - mean_io_u_6: 0.5802
# Epoch 7/200
# 68/68 [==============================] - 23s 337ms/step - loss: 0.6825 - mean_io_u_6: 0.5822
# Epoch 8/200
# 68/68 [==============================] - 23s 335ms/step - loss: 0.6653 - mean_io_u_6: 0.5879
# Epoch 9/200
# 68/68 [==============================] - 23s 336ms/step - loss: 0.6609 - mean_io_u_6: 0.5901
# Epoch 10/200
# 68/68 [==============================] - 23s 335ms/step - loss: 0.6573 - mean_io_u_6: 0.5937
# Epoch 11/200
# 68/68 [==============================] - 23s 335ms/step - loss: 0.6563 - mean_io_u_6: 0.5910
# Epoch 12/200
# 68/68 [==============================] - 23s 337ms/step - loss: 0.6560 - mean_io_u_6: 0.5930
# Epoch 13/200
# 68/68 [==============================] - 23s 338ms/step - loss: 0.6479 - mean_io_u_6: 0.5906
# Epoch 14/200
# 68/68 [==============================] - 23s 337ms/step - loss: 0.6591 - mean_io_u_6: 0.5889
# Epoch 15/200
# 68/68 [==============================] - 23s 337ms/step - loss: 0.6284 - mean_io_u_6: 0.6006
# Epoch 16/200
# 68/68 [==============================] - 23s 339ms/step - loss: 0.6245 - mean_io_u_6: 0.5996
# Epoch 17/200
# 68/68 [==============================] - 23s 337ms/step - loss: 0.6420 - mean_io_u_6: 0.5907
# Epoch 18/200
# 68/68 [==============================] - 23s 340ms/step - loss: 0.6280 - mean_io_u_6: 0.6017
# Epoch 19/200
# 68/68 [==============================] - 23s 337ms/step - loss: 0.6209 - mean_io_u_6: 0.5958
# Epoch 20/200
# 68/68 [==============================] - 23s 338ms/step - loss: 0.6466 - mean_io_u_6: 0.5977
# Epoch 21/200
# 68/68 [==============================] - 23s 336ms/step - loss: 0.6293 - mean_io_u_6: 0.5979
# Epoch 22/200
# 68/68 [==============================] - 23s 336ms/step - loss: 0.6230 - mean_io_u_6: 0.5969
# Epoch 23/200
# 68/68 [==============================] - 23s 337ms/step - loss: 0.6412 - mean_io_u_6: 0.5953
# Epoch 24/200
# 68/68 [==============================] - 23s 336ms/step - loss: 0.6315 - mean_io_u_6: 0.5988
# Epoch 25/200
# 68/68 [==============================] - 23s 336ms/step - loss: 0.6264 - mean_io_u_6: 0.5976
# Epoch 26/200
# 68/68 [==============================] - 23s 335ms/step - loss: 0.6245 - mean_io_u_6: 0.5972
# Epoch 27/200
# 68/68 [==============================] - 23s 334ms/step - loss: 0.6185 - mean_io_u_6: 0.6010
# Epoch 28/200
# 68/68 [==============================] - 23s 337ms/step - loss: 0.6309 - mean_io_u_6: 0.5993
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 29/200
# 68/68 [==============================] - 23s 334ms/step - loss: 0.6154 - mean_io_u_6: 0.5991
# Epoch 30/200
# 68/68 [==============================] - 23s 332ms/step - loss: 0.6165 - mean_io_u_6: 0.6027
# Epoch 31/200
# 68/68 [==============================] - 23s 338ms/step - loss: 0.5885 - mean_io_u_6: 0.6051
# Epoch 32/200
# 68/68 [==============================] - 23s 339ms/step - loss: 0.5959 - mean_io_u_6: 0.6060
# Epoch 33/200
# 68/68 [==============================] - 24s 350ms/step - loss: 0.5817 - mean_io_u_6: 0.6098
# Epoch 34/200
# 68/68 [==============================] - 23s 336ms/step - loss: 0.5895 - mean_io_u_6: 0.6099
# Epoch 35/200
# 68/68 [==============================] - 23s 338ms/step - loss: 0.5946 - mean_io_u_6: 0.6044
# Epoch 36/200
# 68/68 [==============================] - 23s 332ms/step - loss: 0.5833 - mean_io_u_6: 0.6067
# Epoch 37/200
# 68/68 [==============================] - 23s 331ms/step - loss: 0.5903 - mean_io_u_6: 0.6093
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 38/200
# 68/68 [==============================] - 23s 331ms/step - loss: 0.5813 - mean_io_u_6: 0.6109
# Epoch 39/200
# 68/68 [==============================] - 23s 333ms/step - loss: 0.5658 - mean_io_u_6: 0.6109
# Epoch 40/200
# 68/68 [==============================] - 23s 333ms/step - loss: 0.5735 - mean_io_u_6: 0.6108
# Epoch 41/200
# 68/68 [==============================] - 23s 333ms/step - loss: 0.5790 - mean_io_u_6: 0.6102
# Epoch 42/200
# 68/68 [==============================] - 23s 333ms/step - loss: 0.5611 - mean_io_u_6: 0.6141
# Epoch 43/200
# 68/68 [==============================] - 23s 333ms/step - loss: 0.5748 - mean_io_u_6: 0.6092
# Epoch 44/200
# 68/68 [==============================] - 23s 343ms/step - loss: 0.5784 - mean_io_u_6: 0.6062
# Epoch 45/200
# 68/68 [==============================] - 23s 346ms/step - loss: 0.5681 - mean_io_u_6: 0.6066
# Epoch 46/200
# 68/68 [==============================] - 24s 349ms/step - loss: 0.5667 - mean_io_u_6: 0.6096
# Epoch 47/200
# 68/68 [==============================] - 23s 342ms/step - loss: 0.5684 - mean_io_u_6: 0.6094
# Epoch 48/200
# 68/68 [==============================] - 23s 342ms/step - loss: 0.5763 - mean_io_u_6: 0.6098
#
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# [16, 32, 64]
# Epoch 1/200
# 68/68 [==============================] - 26s 340ms/step - loss: 0.9929 - mean_io_u_7: 0.4720
# Epoch 2/200
# 68/68 [==============================] - 23s 338ms/step - loss: 0.9694 - mean_io_u_7: 0.4500
# Epoch 3/200
# 68/68 [==============================] - 23s 338ms/step - loss: 0.8865 - mean_io_u_7: 0.4675
# Epoch 4/200
# 68/68 [==============================] - 23s 346ms/step - loss: 0.7833 - mean_io_u_7: 0.5182
# Epoch 5/200
# 68/68 [==============================] - 24s 360ms/step - loss: 0.6886 - mean_io_u_7: 0.5733
# Epoch 6/200
# 68/68 [==============================] - 24s 359ms/step - loss: 0.6591 - mean_io_u_7: 0.5845
# Epoch 7/200
# 68/68 [==============================] - 23s 342ms/step - loss: 0.6604 - mean_io_u_7: 0.5840
# Epoch 8/200
# 68/68 [==============================] - 23s 342ms/step - loss: 0.6585 - mean_io_u_7: 0.5905
# Epoch 9/200
# 68/68 [==============================] - 23s 343ms/step - loss: 0.6552 - mean_io_u_7: 0.5887
# Epoch 10/200
# 68/68 [==============================] - 23s 339ms/step - loss: 0.6392 - mean_io_u_7: 0.5956
# Epoch 11/200
# 68/68 [==============================] - 23s 340ms/step - loss: 0.6536 - mean_io_u_7: 0.5892
# Epoch 12/200
# 68/68 [==============================] - 23s 346ms/step - loss: 0.6408 - mean_io_u_7: 0.5977
# Epoch 13/200
# 68/68 [==============================] - 23s 341ms/step - loss: 0.6415 - mean_io_u_7: 0.5929
# Epoch 14/200
# 68/68 [==============================] - 23s 343ms/step - loss: 0.6447 - mean_io_u_7: 0.5925
# Epoch 15/200
# 68/68 [==============================] - 23s 341ms/step - loss: 0.6336 - mean_io_u_7: 0.5964
# Epoch 16/200
# 68/68 [==============================] - 23s 340ms/step - loss: 0.6346 - mean_io_u_7: 0.5962
# Epoch 17/200
# 68/68 [==============================] - 23s 342ms/step - loss: 0.6183 - mean_io_u_7: 0.6041
# Epoch 18/200
# 68/68 [==============================] - 23s 343ms/step - loss: 0.6230 - mean_io_u_7: 0.5980
# Epoch 19/200
# 68/68 [==============================] - 23s 343ms/step - loss: 0.6243 - mean_io_u_7: 0.6010
# Epoch 20/200
# 68/68 [==============================] - 23s 341ms/step - loss: 0.6066 - mean_io_u_7: 0.6014
# Epoch 21/200
# 68/68 [==============================] - 23s 341ms/step - loss: 0.6078 - mean_io_u_7: 0.6024
# Epoch 22/200
# 68/68 [==============================] - 23s 346ms/step - loss: 0.6122 - mean_io_u_7: 0.6021
# Epoch 23/200
# 68/68 [==============================] - 23s 340ms/step - loss: 0.6146 - mean_io_u_7: 0.5994
# Epoch 24/200
# 68/68 [==============================] - 23s 341ms/step - loss: 0.6003 - mean_io_u_7: 0.6027
# Epoch 25/200
# 68/68 [==============================] - 24s 346ms/step - loss: 0.6092 - mean_io_u_7: 0.6012
# Epoch 26/200
# 68/68 [==============================] - 23s 345ms/step - loss: 0.6131 - mean_io_u_7: 0.6030
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 27/200
# 68/68 [==============================] - 23s 341ms/step - loss: 0.6018 - mean_io_u_7: 0.6013
# Epoch 28/200
# 68/68 [==============================] - 23s 340ms/step - loss: 0.5868 - mean_io_u_7: 0.6036
# Epoch 29/200
# 68/68 [==============================] - 23s 343ms/step - loss: 0.5752 - mean_io_u_7: 0.6124
# Epoch 30/200
# 68/68 [==============================] - 23s 342ms/step - loss: 0.5775 - mean_io_u_7: 0.6115
# Epoch 31/200
# 68/68 [==============================] - 23s 344ms/step - loss: 0.5788 - mean_io_u_7: 0.6084
# Epoch 32/200
# 68/68 [==============================] - 23s 344ms/step - loss: 0.5632 - mean_io_u_7: 0.6139
# Epoch 33/200
# 68/68 [==============================] - 23s 343ms/step - loss: 0.5596 - mean_io_u_7: 0.6156
# Epoch 34/200
# 68/68 [==============================] - 23s 342ms/step - loss: 0.5735 - mean_io_u_7: 0.6116
# Epoch 35/200
# 68/68 [==============================] - 24s 346ms/step - loss: 0.5722 - mean_io_u_7: 0.6042
# Epoch 36/200
# 68/68 [==============================] - 24s 346ms/step - loss: 0.5625 - mean_io_u_7: 0.6156
# Epoch 37/200
# 68/68 [==============================] - 23s 340ms/step - loss: 0.5493 - mean_io_u_7: 0.6130
# Epoch 38/200
# 68/68 [==============================] - 23s 343ms/step - loss: 0.5607 - mean_io_u_7: 0.6175
# Epoch 39/200
# 68/68 [==============================] - 24s 347ms/step - loss: 0.5614 - mean_io_u_7: 0.6127
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 40/200
# 68/68 [==============================] - 23s 342ms/step - loss: 0.5502 - mean_io_u_7: 0.6147
# Epoch 41/200
# 68/68 [==============================] - 23s 341ms/step - loss: 0.5401 - mean_io_u_7: 0.6171
# Epoch 42/200
# 68/68 [==============================] - 23s 342ms/step - loss: 0.5475 - mean_io_u_7: 0.6166
# Epoch 43/200
# 68/68 [==============================] - 23s 343ms/step - loss: 0.5396 - mean_io_u_7: 0.6177
# Epoch 44/200
# 68/68 [==============================] - 23s 342ms/step - loss: 0.5296 - mean_io_u_7: 0.6217
# Epoch 45/200
# 68/68 [==============================] - 24s 346ms/step - loss: 0.5473 - mean_io_u_7: 0.6185
# Epoch 46/200
# 68/68 [==============================] - 24s 349ms/step - loss: 0.5209 - mean_io_u_7: 0.6255
# Epoch 47/200
# 68/68 [==============================] - 23s 345ms/step - loss: 0.5218 - mean_io_u_7: 0.6240
# Epoch 48/200
# 68/68 [==============================] - 24s 346ms/step - loss: 0.5346 - mean_io_u_7: 0.6146
# Epoch 49/200
# 68/68 [==============================] - 24s 350ms/step - loss: 0.5317 - mean_io_u_7: 0.6218
# Epoch 50/200
# 68/68 [==============================] - 24s 351ms/step - loss: 0.5227 - mean_io_u_7: 0.6201
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 51/200
# 68/68 [==============================] - 23s 345ms/step - loss: 0.5220 - mean_io_u_7: 0.6193
# Epoch 52/200
# 68/68 [==============================] - 23s 345ms/step - loss: 0.5226 - mean_io_u_7: 0.6201
# Epoch 53/200
# 68/68 [==============================] - 23s 345ms/step - loss: 0.5240 - mean_io_u_7: 0.6243
# Epoch 54/200
# 68/68 [==============================] - 23s 344ms/step - loss: 0.5098 - mean_io_u_7: 0.6281
# Epoch 55/200
# 68/68 [==============================] - 24s 346ms/step - loss: 0.5129 - mean_io_u_7: 0.6227
# Epoch 56/200
# 68/68 [==============================] - 24s 346ms/step - loss: 0.5188 - mean_io_u_7: 0.6262
# Epoch 57/200
# 68/68 [==============================] - 24s 356ms/step - loss: 0.5145 - mean_io_u_7: 0.6261
#
# Epoch 00057: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 58/200
# 68/68 [==============================] - 24s 347ms/step - loss: 0.5078 - mean_io_u_7: 0.6271
# Epoch 59/200
# 68/68 [==============================] - 24s 347ms/step - loss: 0.5115 - mean_io_u_7: 0.6262
# Epoch 60/200
# 68/68 [==============================] - 23s 345ms/step - loss: 0.5126 - mean_io_u_7: 0.6230
# Epoch 61/200
# 68/68 [==============================] - 23s 344ms/step - loss: 0.4943 - mean_io_u_7: 0.6350
# Epoch 62/200
# 68/68 [==============================] - 23s 343ms/step - loss: 0.5251 - mean_io_u_7: 0.6254
# Epoch 63/200
# 68/68 [==============================] - 23s 344ms/step - loss: 0.5027 - mean_io_u_7: 0.6290
# Epoch 64/200
# 68/68 [==============================] - 23s 344ms/step - loss: 0.5080 - mean_io_u_7: 0.6289
#
# Epoch 00064: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 65/200
# 68/68 [==============================] - 24s 349ms/step - loss: 0.4998 - mean_io_u_7: 0.6242
# Epoch 66/200
# 68/68 [==============================] - 24s 350ms/step - loss: 0.5028 - mean_io_u_7: 0.6260
# Epoch 67/200
# 68/68 [==============================] - 23s 345ms/step - loss: 0.5089 - mean_io_u_7: 0.6270
# [28, 56]
# Epoch 1/200
# 68/68 [==============================] - 27s 363ms/step - loss: 0.9908 - mean_io_u_8: 0.4814
# Epoch 2/200
# 68/68 [==============================] - 25s 364ms/step - loss: 0.9877 - mean_io_u_8: 0.4246
# Epoch 3/200
# 68/68 [==============================] - 25s 364ms/step - loss: 0.9343 - mean_io_u_8: 0.4665
# Epoch 4/200
# 68/68 [==============================] - 25s 366ms/step - loss: 0.8297 - mean_io_u_8: 0.5002
# Epoch 5/200
# 68/68 [==============================] - 25s 361ms/step - loss: 0.7170 - mean_io_u_8: 0.5696
# Epoch 6/200
# 68/68 [==============================] - 25s 367ms/step - loss: 0.6902 - mean_io_u_8: 0.5782
# Epoch 7/200
# 68/68 [==============================] - 25s 365ms/step - loss: 0.6720 - mean_io_u_8: 0.5856
# Epoch 8/200
# 68/68 [==============================] - 25s 364ms/step - loss: 0.6731 - mean_io_u_8: 0.5821
# Epoch 9/200
# 68/68 [==============================] - 25s 363ms/step - loss: 0.6630 - mean_io_u_8: 0.5855
# Epoch 10/200
# 68/68 [==============================] - 25s 364ms/step - loss: 0.6567 - mean_io_u_8: 0.5894
# Epoch 11/200
# 68/68 [==============================] - 25s 368ms/step - loss: 0.6624 - mean_io_u_8: 0.5840
# Epoch 12/200
# 68/68 [==============================] - 25s 363ms/step - loss: 0.6538 - mean_io_u_8: 0.5885
# Epoch 13/200
# 68/68 [==============================] - 25s 364ms/step - loss: 0.6359 - mean_io_u_8: 0.5883
# Epoch 14/200
# 68/68 [==============================] - 25s 364ms/step - loss: 0.6376 - mean_io_u_8: 0.5950
# Epoch 15/200
# 68/68 [==============================] - 25s 363ms/step - loss: 0.6467 - mean_io_u_8: 0.5884
# Epoch 16/200
# 68/68 [==============================] - 25s 364ms/step - loss: 0.6386 - mean_io_u_8: 0.5912
# Epoch 17/200
# 68/68 [==============================] - 25s 365ms/step - loss: 0.6455 - mean_io_u_8: 0.5885
# Epoch 18/200
# 68/68 [==============================] - 25s 369ms/step - loss: 0.6277 - mean_io_u_8: 0.5920
# Epoch 19/200
# 68/68 [==============================] - 25s 370ms/step - loss: 0.6336 - mean_io_u_8: 0.5882
# Epoch 20/200
# 68/68 [==============================] - 25s 362ms/step - loss: 0.6240 - mean_io_u_8: 0.5928
# Epoch 21/200
# 68/68 [==============================] - 24s 358ms/step - loss: 0.6298 - mean_io_u_8: 0.5922
# Epoch 22/200
# 68/68 [==============================] - 24s 358ms/step - loss: 0.6221 - mean_io_u_8: 0.5939
# Epoch 23/200
# 68/68 [==============================] - 25s 363ms/step - loss: 0.6225 - mean_io_u_8: 0.5916
# Epoch 24/200
# 68/68 [==============================] - 25s 363ms/step - loss: 0.6293 - mean_io_u_8: 0.5894
# Epoch 25/200
# 68/68 [==============================] - 24s 360ms/step - loss: 0.6191 - mean_io_u_8: 0.5949
# Epoch 26/200
# 68/68 [==============================] - 25s 362ms/step - loss: 0.6133 - mean_io_u_8: 0.5958
# Epoch 27/200
# 68/68 [==============================] - 24s 360ms/step - loss: 0.6074 - mean_io_u_8: 0.5938
# Epoch 28/200
# 68/68 [==============================] - 24s 360ms/step - loss: 0.6011 - mean_io_u_8: 0.5981
# Epoch 29/200
# 68/68 [==============================] - 24s 357ms/step - loss: 0.6222 - mean_io_u_8: 0.5902
# Epoch 30/200
# 68/68 [==============================] - 24s 361ms/step - loss: 0.6360 - mean_io_u_8: 0.5903
# Epoch 31/200
# 68/68 [==============================] - 24s 360ms/step - loss: 0.5980 - mean_io_u_8: 0.6058
# Epoch 32/200
# 68/68 [==============================] - 25s 363ms/step - loss: 0.6151 - mean_io_u_8: 0.5938
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 33/200
# 68/68 [==============================] - 24s 358ms/step - loss: 0.6033 - mean_io_u_8: 0.5985
# Epoch 34/200
# 68/68 [==============================] - 24s 357ms/step - loss: 0.5854 - mean_io_u_8: 0.6024
# Epoch 35/200
# 68/68 [==============================] - 24s 359ms/step - loss: 0.5774 - mean_io_u_8: 0.6023
# Epoch 36/200
# 68/68 [==============================] - 24s 359ms/step - loss: 0.5732 - mean_io_u_8: 0.6035
# Epoch 37/200
# 68/68 [==============================] - 24s 357ms/step - loss: 0.5724 - mean_io_u_8: 0.6023
# Epoch 38/200
# 68/68 [==============================] - 24s 357ms/step - loss: 0.5636 - mean_io_u_8: 0.6078
# Epoch 39/200
# 68/68 [==============================] - 24s 357ms/step - loss: 0.5758 - mean_io_u_8: 0.6046
# Epoch 40/200
# 68/68 [==============================] - 24s 359ms/step - loss: 0.5747 - mean_io_u_8: 0.6048
# Epoch 41/200
# 68/68 [==============================] - 24s 357ms/step - loss: 0.5714 - mean_io_u_8: 0.6051
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 42/200
# 68/68 [==============================] - 24s 359ms/step - loss: 0.5667 - mean_io_u_8: 0.6056
# Epoch 43/200
# 68/68 [==============================] - 25s 361ms/step - loss: 0.5642 - mean_io_u_8: 0.6058
# Epoch 44/200
# 68/68 [==============================] - 24s 356ms/step - loss: 0.5471 - mean_io_u_8: 0.6087
# Epoch 45/200
# 68/68 [==============================] - 24s 357ms/step - loss: 0.5584 - mean_io_u_8: 0.6092
# Epoch 46/200
# 68/68 [==============================] - 24s 359ms/step - loss: 0.5526 - mean_io_u_8: 0.6120
# Epoch 47/200
# 68/68 [==============================] - 24s 357ms/step - loss: 0.5408 - mean_io_u_8: 0.6135
# Epoch 48/200
# 68/68 [==============================] - 24s 356ms/step - loss: 0.5558 - mean_io_u_8: 0.6087
# Epoch 49/200
# 68/68 [==============================] - 24s 360ms/step - loss: 0.5450 - mean_io_u_8: 0.6115
# Epoch 50/200
# 68/68 [==============================] - 24s 359ms/step - loss: 0.5449 - mean_io_u_8: 0.6138
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 51/200
# 68/68 [==============================] - 24s 358ms/step - loss: 0.5551 - mean_io_u_8: 0.6093
# Epoch 52/200
# 68/68 [==============================] - 24s 355ms/step - loss: 0.5447 - mean_io_u_8: 0.6085
# Epoch 53/200
# 68/68 [==============================] - 24s 357ms/step - loss: 0.5513 - mean_io_u_8: 0.6125
# Epoch 54/200
# 68/68 [==============================] - 24s 359ms/step - loss: 0.5392 - mean_io_u_8: 0.6128
# Epoch 55/200
# 68/68 [==============================] - 24s 358ms/step - loss: 0.5368 - mean_io_u_8: 0.6158
# Epoch 56/200
# 68/68 [==============================] - 24s 359ms/step - loss: 0.5410 - mean_io_u_8: 0.6122
# Epoch 57/200
# 68/68 [==============================] - 25s 362ms/step - loss: 0.5249 - mean_io_u_8: 0.6174
# Epoch 58/200
# 68/68 [==============================] - 25s 362ms/step - loss: 0.5313 - mean_io_u_8: 0.6146
#
# Epoch 00058: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 59/200
# 68/68 [==============================] - 24s 357ms/step - loss: 0.5542 - mean_io_u_8: 0.6080
# Epoch 60/200
# 68/68 [==============================] - 24s 358ms/step - loss: 0.5429 - mean_io_u_8: 0.6140
# Epoch 61/200
# 68/68 [==============================] - 24s 356ms/step - loss: 0.5324 - mean_io_u_8: 0.6142
# Epoch 62/200
# 68/68 [==============================] - 24s 358ms/step - loss: 0.5330 - mean_io_u_8: 0.6151
# Epoch 63/200
# 68/68 [==============================] - 24s 355ms/step - loss: 0.5222 - mean_io_u_8: 0.6207
# Epoch 64/200
# 68/68 [==============================] - 24s 357ms/step - loss: 0.5404 - mean_io_u_8: 0.6147
# Epoch 65/200
# 68/68 [==============================] - 24s 358ms/step - loss: 0.5284 - mean_io_u_8: 0.6207
# Epoch 66/200
# 68/68 [==============================] - 24s 355ms/step - loss: 0.5345 - mean_io_u_8: 0.6171
# Epoch 67/200
# 68/68 [==============================] - 25s 361ms/step - loss: 0.5222 - mean_io_u_8: 0.6189
# Epoch 68/200
# 68/68 [==============================] - 24s 357ms/step - loss: 0.5255 - mean_io_u_8: 0.6177
# Epoch 69/200
# 68/68 [==============================] - 24s 355ms/step - loss: 0.5212 - mean_io_u_8: 0.6203
#
# Epoch 00069: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.

# %%
for i,hist in enumerate(histories):
  plt.plot(hist.history['loss'],label="{} layers".format(configs[i][00]))
plt.legend()
plt.title('loss')
plt.show()
for i,hist in enumerate(histories):
  plt.plot(hist.history['mean_io_u_{}'.format(str(i+6))],label="{} layers".format(configs[i][0]))
plt.legend()
plt.title('mean_io_u score')
plt.show()

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import f1_score
from sklearn.metrics import auc
from sklearn.metrics import precision_recall_curve,precision_score,recall_score

# %% [markdown]
# #test data

# %%
# data
data_location = "/content/drive/My Drive/IDRid/A. Segmentation/1. Original Images/b. Testing Set"
test_data = []  # create an empty list
for (dirName, subdirList, fileList) in sorted(os.walk(data_location)):
    for fileName in sorted(fileList):
        if ".jpg" in fileName.lower() :
            test_data.append(os.path.join(dirName,fileName))
print(len(test_data))
target_root_location = "/content/drive/My Drive/IDRid/A. Segmentation/2. All Segmentation Groundtruths/b. Testing Set/"

test_data_gt = []  # create an empty list
segs=['1. Microaneurysms','2. Haemorrhages','3. Hard Exudates','4. Soft Exudates']
for seg in segs:
  data_location=target_root_location+seg
  print(data_location)
  seg_mask=[]
  for dirName, subdirList, fileList in sorted(os.walk(data_location)):
      for filename in sorted(fileList):
          if ".tif" in filename.lower() :
              seg_mask.append(os.path.join(dirName,filename))
              
  test_data_gt.append(seg_mask)
print(len(test_data_gt));
# Out:
# 27
# /content/drive/My Drive/IDRid/A. Segmentation/2. All Segmentation Groundtruths/b. Testing Set/1. Microaneurysms
# /content/drive/My Drive/IDRid/A. Segmentation/2. All Segmentation Groundtruths/b. Testing Set/2. Haemorrhages
# /content/drive/My Drive/IDRid/A. Segmentation/2. All Segmentation Groundtruths/b. Testing Set/3. Hard Exudates
# /content/drive/My Drive/IDRid/A. Segmentation/2. All Segmentation Groundtruths/b. Testing Set/4. Soft Exudates
# 4

# %%
test_batch = np.zeros(shape = (len(test_data_gt[0]), 512, 512, 3));
#test_labels_ls=[]
test_label = np.zeros(shape = (len(test_data_gt[0]), 512, 512, 1));
img_index=0
lbl_index=0
test_img_inds=[]
for file_index in range(0,len(test_data_gt[0])):
    # label
    lbl = cv2.cvtColor(imread(test_data_gt[0][int(file_index)]), cv2.COLOR_BGRA2BGR)
    lbl = cv2.cvtColor(lbl, cv2.COLOR_BGR2GRAY) 
    lbl_index=int(test_data_gt[0][int(file_index)][-9:-7])
    img_index=lbl_index
    test_img_inds.append(img_index)
    # image
    img=imread(test_data[img_index-1-54])
    #preprocess    
    img,lbl=preprocess_image(img,lbl)
    test_batch[file_index, :, :,:],test_label[file_index, :, :,:]  = img,np.expand_dims(resize(lbl, (512, 512)), axis = 2)
    
test_batch  = test_batch/255
test_label  = test_label / np.max(test_label)

mask = test_label[:,:,:,:] > 0.25
test_label[mask] = 1.0
test_label[~mask] = 0.0

print(test_batch.shape)
print(test_label.shape)
# Out:
# (27, 512, 512, 3)
# (27, 512, 512, 1)

# %%
#test_img_inds

# %%
"""print(test_batch.shape)
print(test_label.shape)
plt.imshow(test_batch[2])
plt.show()
plt.imshow(np.squeeze(test_label[2]))
plt.show()"""
# Out:
# 'print(test_batch.shape)\nprint(test_label.shape)\nplt.imshow(test_batch[2])\nplt.show()\nplt.imshow(np.squeeze(test_label[2]))\nplt.show()'

# %%
for j,model in enumerate(models):
  print(configs[j], "layers")
  predicted_test_label=np.zeros(test_label.shape)
  for i in range(len(test_data_gt[0])):
    predicted_test_label[i]=models[j].predict(np.expand_dims(test_batch[i],axis=0))
  
  # ROC
  test_auc = roc_auc_score(test_label.reshape(-1),predicted_test_label.reshape(-1))
  #train_auc = roc_auc_score(train_label.reshape(-1),predicted_train_label.reshape(-1))
  print("train ",0," test roc",test_auc)
  
  # F1
  testy, yhat_classes=(test_label.reshape(-1),np.round(predicted_test_label.reshape(-1)))
  test_f1 = f1_score(testy, yhat_classes)
  #testy, yhat_classes=train_label.reshape(-1),np.round(predicted_train_label.reshape(-1))
  #train_f1 = f1_score(testy, yhat_classes)
  train_f1=0
  print('Train  F1 score: %f' % train_f1,'Test F1 score: %f' % test_f1)

  #accuracy
  accuracy = accuracy_score(testy, yhat_classes)
  print('Accuracy: %f' % accuracy)
  #AUPR
  
  test_aupr = precision_recall_curve(test_label.reshape(-1),predicted_test_label.reshape(-1))
  train_auc=0
  test_auc=auc(test_aupr[1],test_aupr[0] )
  print("natural threshold train AUPR",train_auc," test AUPR",test_auc)
  
  #plot Precision recall curve
  plt.plot(test_aupr[1],test_aupr[0])
  plt.ylabel('Precision')
  plt.xlabel('Recall')
  plt.show()
  #del predicted_test_label
# Out:
# [3, 14] layers
# train  0  test roc 0.8239300870477374
# Train  F1 score: 0.000000 Test F1 score: 0.339263
# Accuracy: 0.998746
# natural threshold train AUPR 0  test AUPR 0.2519758059354082
# [3, 16] layers
# train  0  test roc 0.8049329247043155
# Train  F1 score: 0.000000 Test F1 score: 0.393798
# Accuracy: 0.998729
# natural threshold train AUPR 0  test AUPR 0.27581810083911545
# [2, 28] layers
# train  0  test roc 0.851956655179435
# Train  F1 score: 0.000000 Test F1 score: 0.380703
# Accuracy: 0.998696
# natural threshold train AUPR 0  test AUPR 0.2774416671284644

# %%
for i in range(len(test_data_gt[0])):
    predicted_test_label[i]=models[1].predict(np.expand_dims(test_batch[i],axis=0))
print(predicted_test_label[0].shape)
for i in range(1,1,1):
    plt.imshow(test_batch[i,:,:,:])
    plt.title("Image")
    plt.show()  
    plt.imshow(np.squeeze(predicted_test_label[i,:,:,:], axis = 2),cmap='gray')
    plt.title("Predicted mask")
    plt.show()
    plt.imshow(np.squeeze(test_label[i,:,:,:], axis = 2), cmap='gray')
    plt.title("Actual mask")
    plt.show()
# Out:
# (512, 512, 1)

# %% [markdown]
# #individaul test scores

# %%
def dice_score(y_true, y_pred, smooth=1):
  intersection = K.sum(y_true * y_pred, axis=[1,2,3])
  union = K.sum(y_true, axis=[1,2,3]) + K.sum(y_pred, axis=[1,2,3])
  dice = K.mean((2. * intersection + smooth)/(union + smooth), axis=0)
  return dice

# %%
f1_scores=[]
aupr=[]
for i in range(len(test_data_gt[0])):
  # F1
  testy, yhat_classes=(np.expand_dims(test_label[i],axis=0),np.expand_dims(predicted_test_label[i],axis=0))
  test_f1 = dice_score(testy, yhat_classes).numpy()
  train_f1=0
  #print('Train  F1 score: %f' % train_f1,'Test F1 score: %f' % test_f1)
  f1_scores.append(test_f1)
  #AUPR
  test_aupr = precision_recall_curve(test_label[i].reshape(-1),predicted_test_label[i].reshape(-1))
  train_auc=0
  test_auc=auc(test_aupr[1],test_aupr[0] )
  #print("Train AUPR",train_auc," test AUPR",test_auc)
  aupr.append(test_auc)

# %%
import pandas as pd
print("median AUPR",np.quantile(aupr,q=0.5)," median F1",np.median(f1_scores))
df = pd.DataFrame(np.array([aupr,f1_scores]).reshape(27,2), columns=['aupr','f1'])
df.plot.box(grid='True')
# Out:
# median AUPR 0.27434280689812407  median F1 0.3749359747480492

# %% [markdown]
# ## 4 layer 4 filter model is already saved in drive

# %%
 # serialize model to JSON
model_json = models[1].to_json()
with open("/content/drive/MyDrive/IDRid/Experimental models/seg_MA_ben_sigm8_3l_16f.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
models[1].save_weights("/content/drive/MyDrive/IDRid/Experimental models/seg_MA_ben_sigm8_3l_16f.h5")
print("Saved model to disk")
# Out:
# Saved model to disk
